# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in /opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in /opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from sklearn) (0.23.2)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from scikit-learn->sklearn) (0.16.0)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in /opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.5.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.18.5)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in /opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (0.16.0)

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("../Resources/exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
df.keys()
# Out:
# Index(['koi_disposition', 'koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
#        'koi_fpflag_ec', 'koi_period', 'koi_period_err1', 'koi_period_err2',
#        'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact',
#        'koi_impact_err1', 'koi_impact_err2', 'koi_duration',
#        'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1',
#        'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2',
#        'koi_teq', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2',
#        'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff', 'koi_steff_err1',
#        'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2',
#        'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec',
#        'koi_kepmag'],
#       dtype='object')

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
X = df.drop('koi_disposition', axis=1)
X.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0         -0.003520  ...             -81      4.467           0.064
# 1         -0.000581  ...            -176      4.544           0.044
# 2         -0.000115  ...            -174      4.564           0.053
# 3         -0.001130  ...            -211      4.438           0.070
# 4         -0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 40 columns]

# %% [markdown]
# y: koi_disposition
# X: koi_score, koi_period (orbital period), koi_impact, koi_duration(transit duration), koi_depth, koi_prad, koi_teq,

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

label_encoder.fit(df["koi_disposition"])
label_encoder.classes_

y = label_encoder.transform(df["koi_disposition"])
y
# Out:
# array([1, 2, 2, ..., 0, 2, 2])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 4410              0              1              1              0    1.049407
# 5814              0              1              0              1    8.653040
# 6745              0              1              0              0   14.443127
# 3045              0              0              0              0    0.849907
# 905               0              0              0              0   52.069002
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 4410         0.000002        -0.000002   131.803280          0.001930
# 5814         0.000029        -0.000029   136.667980          0.003080
# 6745         0.000002        -0.000002   139.390317          0.000093
# 3045         0.000004        -0.000004   131.674100          0.003510
# 905          0.000196        -0.000196   178.155250          0.002840
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 4410         -0.001930  ...             -70      2.425           0.035
# 5814         -0.003080  ...            -159      4.528           0.051
# 6745         -0.000093  ...            -183      3.672           0.323
# 3045         -0.003510  ...            -140      4.733           0.066
# 905          -0.002840  ...             -83      4.251           0.149
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 4410          -0.031    13.417          0.466         -2.642  299.19092
# 5814          -0.110     0.840          0.138         -0.080  289.08063
# 6745          -0.108     2.736          0.476         -1.110  300.12634
# 3045          -0.033     0.505          0.039         -0.054  293.28802
# 905           -0.108     1.246          0.179         -0.219  289.67935
#
#             dec  koi_kepmag
# 4410  40.822639      12.387
# 5814  40.026791      15.639
# 6745  45.633549      12.732
# 3045  43.514992      15.220
# 905   40.700459      14.279
#
# [5 rows x 40 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %% [markdown]
# # Train the Model

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state=1)
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=1)

# %%
import numpy as np
np.array(y_test)
# Out:
# array([2, 0, 0, ..., 0, 2, 2])

# %%
predictions = rf.predict(X_test)

for x in range(0,5,1):
    print(f"Predictions: {predictions[x]}, Actual: {y_test[x]}")
# Out:
# Predictions: 2, Actual: 2
# Predictions: 0, Actual: 0
# Predictions: 1, Actual: 0
# Predictions: 2, Actual: 2
# Predictions: 0, Actual: 0

# %%
print(f"Training Data Score: {rf.score(X_train, y_train)}")
print(f"Testing Data Score: {rf.score(X_test, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.8901601830663616

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# codes I referred to : https://www.kaggle.com/sociopath00/random-forest-using-gridsearchcv
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV

param_grid = { 
    'n_estimators': [200,500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [5,8,10],
    'criterion' :['gini', 'entropy']
}
grid_rf = GridSearchCV(rf, param_grid, verbose=3)

# %%
# List the parameters
rf.get_params().keys()
# Out:
# dict_keys(['bootstrap', 'ccp_alpha', 'class_weight', 'criterion', 'max_depth', 'max_features', 'max_leaf_nodes', 'max_samples', 'min_impurity_decrease', 'min_impurity_split', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'n_estimators', 'n_jobs', 'oob_score', 'random_state', 'verbose', 'warm_start'])

# %%
# Train the model with GridSearch
grid_rf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] criterion=gini, max_depth=5, max_features=auto, n_estimators=200
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  criterion=gini, max_depth=5, max_features=auto, n_estimators=200, score=0.874, total=   3.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, n_estimators=200
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.0s remaining:    0.0s
# [CV]  criterion=gini, max_depth=5, max_features=auto, n_estimators=200, score=0.870, total=   2.9s
# [CV] criterion=gini, max_depth=5, max_features=auto, n_estimators=200
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.9s remaining:    0.0s
# [CV]  criterion=gini, max_depth=5, max_features=auto, n_estimators=200, score=0.868, total=   2.7s
# [CV] criterion=gini, max_depth=5, max_features=auto, n_estimators=200
# [CV]  criterion=gini, max_depth=5, max_features=auto, n_estimators=200, score=0.862, total=   2.9s
# [CV] criterion=gini, max_depth=5, max_features=auto, n_estimators=200
# [CV]  criterion=gini, max_depth=5, max_features=auto, n_estimators=200, score=0.846, total=   2.8s
# [CV] criterion=gini, max_depth=5, max_features=auto, n_estimators=500
# [CV]  criterion=gini, max_depth=5, max_features=auto, n_estimators=500, score=0.874, total=   7.2s
# [CV] criterion=gini, max_depth=5, max_features=auto, n_estimators=500
# [CV]  criterion=gini, max_depth=5, max_features=auto, n_estimators=500, score=0.869, total=   7.3s
# [CV] criterion=gini, max_depth=5, max_features=auto, n_estimators=500
# [CV]  criterion=gini, max_depth=5, max_features=auto, n_estimators=500, score=0.870, total=   6.9s
# [CV] criterion=gini, max_depth=5, max_features=auto, n_estimators=500
# [CV]  criterion=gini, max_depth=5, max_features=auto, n_estimators=500, score=0.860, total=   7.0s
# [CV] criterion=gini, max_depth=5, max_features=auto, n_estimators=500
# [CV]  criterion=gini, max_depth=5, max_features=auto, n_estimators=500, score=0.849, total=   7.2s
# [CV] criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200
# [CV]  criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200, score=0.874, total=   2.8s
# [CV] criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200
# [CV]  criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200, score=0.870, total=   2.9s
# [CV] criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200
# [CV]  criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200, score=0.868, total=   3.0s
# [CV] criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200
# [CV]  criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200, score=0.862, total=   3.2s
# [CV] criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200
# [CV]  criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200, score=0.846, total=   3.4s
# [CV] criterion=gini, max_depth=5, max_features=sqrt, n_estimators=500
# [CV]  criterion=gini, max_depth=5, max_features=sqrt, n_estimators=500, score=0.874, total=   8.0s
# [CV] criterion=gini, max_depth=5, max_features=sqrt, n_estimators=500
# [CV]  criterion=gini, max_depth=5, max_features=sqrt, n_estimators=500, score=0.869, total=  10.3s
# [CV] criterion=gini, max_depth=5, max_features=sqrt, n_estimators=500
# [CV]  criterion=gini, max_depth=5, max_features=sqrt, n_estimators=500, score=0.870, total=   6.5s
# [CV] criterion=gini, max_depth=5, max_features=sqrt, n_estimators=500
# [CV]  criterion=gini, max_depth=5, max_features=sqrt, n_estimators=500, score=0.860, total=   5.5s
# [CV] criterion=gini, max_depth=5, max_features=sqrt, n_estimators=500
# [CV]  criterion=gini, max_depth=5, max_features=sqrt, n_estimators=500, score=0.849, total=   6.1s
# [CV] criterion=gini, max_depth=5, max_features=log2, n_estimators=200
# [CV]  criterion=gini, max_depth=5, max_features=log2, n_estimators=200, score=0.861, total=   1.7s
# [CV] criterion=gini, max_depth=5, max_features=log2, n_estimators=200
# [CV]  criterion=gini, max_depth=5, max_features=log2, n_estimators=200, score=0.863, total=   1.7s
# [CV] criterion=gini, max_depth=5, max_features=log2, n_estimators=200
# [CV]  criterion=gini, max_depth=5, max_features=log2, n_estimators=200, score=0.868, total=   1.8s
# [CV] criterion=gini, max_depth=5, max_features=log2, n_estimators=200
# [CV]  criterion=gini, max_depth=5, max_features=log2, n_estimators=200, score=0.865, total=   1.7s
# [CV] criterion=gini, max_depth=5, max_features=log2, n_estimators=200
# [CV]  criterion=gini, max_depth=5, max_features=log2, n_estimators=200, score=0.845, total=   1.8s
# [CV] criterion=gini, max_depth=5, max_features=log2, n_estimators=500
# [CV]  criterion=gini, max_depth=5, max_features=log2, n_estimators=500, score=0.865, total=   5.5s
# [CV] criterion=gini, max_depth=5, max_features=log2, n_estimators=500
# [CV]  criterion=gini, max_depth=5, max_features=log2, n_estimators=500, score=0.865, total=   5.1s
# [CV] criterion=gini, max_depth=5, max_features=log2, n_estimators=500
# [CV]  criterion=gini, max_depth=5, max_features=log2, n_estimators=500, score=0.870, total=   4.1s
# [CV] criterion=gini, max_depth=5, max_features=log2, n_estimators=500
# [CV]  criterion=gini, max_depth=5, max_features=log2, n_estimators=500, score=0.862, total=   4.9s
# [CV] criterion=gini, max_depth=5, max_features=log2, n_estimators=500
# [CV]  criterion=gini, max_depth=5, max_features=log2, n_estimators=500, score=0.844, total=   4.3s
# [CV] criterion=gini, max_depth=8, max_features=auto, n_estimators=200
# [CV]  criterion=gini, max_depth=8, max_features=auto, n_estimators=200, score=0.896, total=   2.7s
# [CV] criterion=gini, max_depth=8, max_features=auto, n_estimators=200
# [CV]  criterion=gini, max_depth=8, max_features=auto, n_estimators=200, score=0.883, total=   2.9s
# [CV] criterion=gini, max_depth=8, max_features=auto, n_estimators=200
# [CV]  criterion=gini, max_depth=8, max_features=auto, n_estimators=200, score=0.891, total=   3.1s
# [CV] criterion=gini, max_depth=8, max_features=auto, n_estimators=200
# [CV]  criterion=gini, max_depth=8, max_features=auto, n_estimators=200, score=0.887, total=   2.9s
# [CV] criterion=gini, max_depth=8, max_features=auto, n_estimators=200
# [CV]  criterion=gini, max_depth=8, max_features=auto, n_estimators=200, score=0.871, total=   2.8s
# [CV] criterion=gini, max_depth=8, max_features=auto, n_estimators=500
# [CV]  criterion=gini, max_depth=8, max_features=auto, n_estimators=500, score=0.897, total=   9.3s
# [CV] criterion=gini, max_depth=8, max_features=auto, n_estimators=500
# [CV]  criterion=gini, max_depth=8, max_features=auto, n_estimators=500, score=0.879, total=  10.6s
# [CV] criterion=gini, max_depth=8, max_features=auto, n_estimators=500
# [CV]  criterion=gini, max_depth=8, max_features=auto, n_estimators=500, score=0.891, total=   9.2s
# [CV] criterion=gini, max_depth=8, max_features=auto, n_estimators=500
# [CV]  criterion=gini, max_depth=8, max_features=auto, n_estimators=500, score=0.887, total=   6.8s
# [CV] criterion=gini, max_depth=8, max_features=auto, n_estimators=500
# [CV]  criterion=gini, max_depth=8, max_features=auto, n_estimators=500, score=0.868, total=   7.4s
# [CV] criterion=gini, max_depth=8, max_features=sqrt, n_estimators=200
# [CV]  criterion=gini, max_depth=8, max_features=sqrt, n_estimators=200, score=0.896, total=   2.5s
# [CV] criterion=gini, max_depth=8, max_features=sqrt, n_estimators=200
# [CV]  criterion=gini, max_depth=8, max_features=sqrt, n_estimators=200, score=0.883, total=   2.4s
# [CV] criterion=gini, max_depth=8, max_features=sqrt, n_estimators=200
# [CV]  criterion=gini, max_depth=8, max_features=sqrt, n_estimators=200, score=0.891, total=   2.7s
# [CV] criterion=gini, max_depth=8, max_features=sqrt, n_estimators=200
# [CV]  criterion=gini, max_depth=8, max_features=sqrt, n_estimators=200, score=0.887, total=   2.8s
# [CV] criterion=gini, max_depth=8, max_features=sqrt, n_estimators=200
# [CV]  criterion=gini, max_depth=8, max_features=sqrt, n_estimators=200, score=0.871, total=   3.2s
# [CV] criterion=gini, max_depth=8, max_features=sqrt, n_estimators=500
# [CV]  criterion=gini, max_depth=8, max_features=sqrt, n_estimators=500, score=0.897, total=   7.6s
# [CV] criterion=gini, max_depth=8, max_features=sqrt, n_estimators=500
# [CV]  criterion=gini, max_depth=8, max_features=sqrt, n_estimators=500, score=0.879, total=   7.1s
# [CV] criterion=gini, max_depth=8, max_features=sqrt, n_estimators=500
# [CV]  criterion=gini, max_depth=8, max_features=sqrt, n_estimators=500, score=0.891, total=   7.5s
# [CV] criterion=gini, max_depth=8, max_features=sqrt, n_estimators=500
# [CV]  criterion=gini, max_depth=8, max_features=sqrt, n_estimators=500, score=0.887, total=   6.2s
# [CV] criterion=gini, max_depth=8, max_features=sqrt, n_estimators=500
# [CV]  criterion=gini, max_depth=8, max_features=sqrt, n_estimators=500, score=0.868, total=   7.2s
# [CV] criterion=gini, max_depth=8, max_features=log2, n_estimators=200
# [CV]  criterion=gini, max_depth=8, max_features=log2, n_estimators=200, score=0.890, total=   6.8s
# [CV] criterion=gini, max_depth=8, max_features=log2, n_estimators=200
# [CV]  criterion=gini, max_depth=8, max_features=log2, n_estimators=200, score=0.880, total=   2.9s
# [CV] criterion=gini, max_depth=8, max_features=log2, n_estimators=200
# [CV]  criterion=gini, max_depth=8, max_features=log2, n_estimators=200, score=0.886, total=   2.6s
# [CV] criterion=gini, max_depth=8, max_features=log2, n_estimators=200
# [CV]  criterion=gini, max_depth=8, max_features=log2, n_estimators=200, score=0.888, total=   2.4s
# [CV] criterion=gini, max_depth=8, max_features=log2, n_estimators=200
# [CV]  criterion=gini, max_depth=8, max_features=log2, n_estimators=200, score=0.870, total=   2.5s
# [CV] criterion=gini, max_depth=8, max_features=log2, n_estimators=500
# [CV]  criterion=gini, max_depth=8, max_features=log2, n_estimators=500, score=0.893, total=   6.6s
# [CV] criterion=gini, max_depth=8, max_features=log2, n_estimators=500
# [CV]  criterion=gini, max_depth=8, max_features=log2, n_estimators=500, score=0.879, total=   6.4s
# [CV] criterion=gini, max_depth=8, max_features=log2, n_estimators=500
# [CV]  criterion=gini, max_depth=8, max_features=log2, n_estimators=500, score=0.888, total=   5.9s
# [CV] criterion=gini, max_depth=8, max_features=log2, n_estimators=500
# [CV]  criterion=gini, max_depth=8, max_features=log2, n_estimators=500, score=0.885, total=   6.0s
# [CV] criterion=gini, max_depth=8, max_features=log2, n_estimators=500
# [CV]  criterion=gini, max_depth=8, max_features=log2, n_estimators=500, score=0.866, total=   6.3s
# [CV] criterion=gini, max_depth=10, max_features=auto, n_estimators=200
# [CV]  criterion=gini, max_depth=10, max_features=auto, n_estimators=200, score=0.899, total=   3.5s
# [CV] criterion=gini, max_depth=10, max_features=auto, n_estimators=200
# [CV]  criterion=gini, max_depth=10, max_features=auto, n_estimators=200, score=0.887, total=   2.9s
# [CV] criterion=gini, max_depth=10, max_features=auto, n_estimators=200
# [CV]  criterion=gini, max_depth=10, max_features=auto, n_estimators=200, score=0.891, total=   3.0s
# [CV] criterion=gini, max_depth=10, max_features=auto, n_estimators=200
# [CV]  criterion=gini, max_depth=10, max_features=auto, n_estimators=200, score=0.895, total=   3.0s
# [CV] criterion=gini, max_depth=10, max_features=auto, n_estimators=200
# [CV]  criterion=gini, max_depth=10, max_features=auto, n_estimators=200, score=0.878, total=   3.1s
# [CV] criterion=gini, max_depth=10, max_features=auto, n_estimators=500
# [CV]  criterion=gini, max_depth=10, max_features=auto, n_estimators=500, score=0.899, total=   7.6s
# [CV] criterion=gini, max_depth=10, max_features=auto, n_estimators=500
# [CV]  criterion=gini, max_depth=10, max_features=auto, n_estimators=500, score=0.886, total=   7.4s
# [CV] criterion=gini, max_depth=10, max_features=auto, n_estimators=500
# [CV]  criterion=gini, max_depth=10, max_features=auto, n_estimators=500, score=0.893, total=   7.6s
# [CV] criterion=gini, max_depth=10, max_features=auto, n_estimators=500
# [CV]  criterion=gini, max_depth=10, max_features=auto, n_estimators=500, score=0.897, total=   7.4s
# [CV] criterion=gini, max_depth=10, max_features=auto, n_estimators=500
# [CV]  criterion=gini, max_depth=10, max_features=auto, n_estimators=500, score=0.880, total=   7.6s
# [CV] criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV]  criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200, score=0.899, total=   2.9s
# [CV] criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV]  criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200, score=0.887, total=   3.3s
# [CV] criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV]  criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200, score=0.891, total=   3.0s
# [CV] criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV]  criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200, score=0.895, total=   3.0s
# [CV] criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV]  criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200, score=0.878, total=   3.0s
# [CV] criterion=gini, max_depth=10, max_features=sqrt, n_estimators=500
# [CV]  criterion=gini, max_depth=10, max_features=sqrt, n_estimators=500, score=0.899, total=   8.1s
# [CV] criterion=gini, max_depth=10, max_features=sqrt, n_estimators=500
# [CV]  criterion=gini, max_depth=10, max_features=sqrt, n_estimators=500, score=0.886, total=   7.4s
# [CV] criterion=gini, max_depth=10, max_features=sqrt, n_estimators=500
# [CV]  criterion=gini, max_depth=10, max_features=sqrt, n_estimators=500, score=0.893, total=   8.0s
# [CV] criterion=gini, max_depth=10, max_features=sqrt, n_estimators=500
# [CV]  criterion=gini, max_depth=10, max_features=sqrt, n_estimators=500, score=0.897, total=   8.3s
# [CV] criterion=gini, max_depth=10, max_features=sqrt, n_estimators=500
# [CV]  criterion=gini, max_depth=10, max_features=sqrt, n_estimators=500, score=0.880, total=   8.0s
# [CV] criterion=gini, max_depth=10, max_features=log2, n_estimators=200
# [CV]  criterion=gini, max_depth=10, max_features=log2, n_estimators=200, score=0.898, total=   2.9s
# [CV] criterion=gini, max_depth=10, max_features=log2, n_estimators=200
# [CV]  criterion=gini, max_depth=10, max_features=log2, n_estimators=200, score=0.883, total=   2.9s
# [CV] criterion=gini, max_depth=10, max_features=log2, n_estimators=200
# [CV]  criterion=gini, max_depth=10, max_features=log2, n_estimators=200, score=0.895, total=   3.3s
# [CV] criterion=gini, max_depth=10, max_features=log2, n_estimators=200
# [CV]  criterion=gini, max_depth=10, max_features=log2, n_estimators=200, score=0.892, total=   2.9s
# [CV] criterion=gini, max_depth=10, max_features=log2, n_estimators=200
# [CV]  criterion=gini, max_depth=10, max_features=log2, n_estimators=200, score=0.876, total=   2.5s
# [CV] criterion=gini, max_depth=10, max_features=log2, n_estimators=500
# [CV]  criterion=gini, max_depth=10, max_features=log2, n_estimators=500, score=0.899, total=   7.1s
# [CV] criterion=gini, max_depth=10, max_features=log2, n_estimators=500
# [CV]  criterion=gini, max_depth=10, max_features=log2, n_estimators=500, score=0.885, total=   7.4s
# [CV] criterion=gini, max_depth=10, max_features=log2, n_estimators=500
# [CV]  criterion=gini, max_depth=10, max_features=log2, n_estimators=500, score=0.898, total=   7.3s
# [CV] criterion=gini, max_depth=10, max_features=log2, n_estimators=500
# [CV]  criterion=gini, max_depth=10, max_features=log2, n_estimators=500, score=0.889, total=   6.9s
# [CV] criterion=gini, max_depth=10, max_features=log2, n_estimators=500
# [CV]  criterion=gini, max_depth=10, max_features=log2, n_estimators=500, score=0.872, total=   9.0s
# [CV] criterion=entropy, max_depth=5, max_features=auto, n_estimators=200
# [CV]  criterion=entropy, max_depth=5, max_features=auto, n_estimators=200, score=0.878, total=   2.8s
# [CV] criterion=entropy, max_depth=5, max_features=auto, n_estimators=200
# [CV]  criterion=entropy, max_depth=5, max_features=auto, n_estimators=200, score=0.867, total=   2.8s
# [CV] criterion=entropy, max_depth=5, max_features=auto, n_estimators=200
# [CV]  criterion=entropy, max_depth=5, max_features=auto, n_estimators=200, score=0.871, total=   2.8s
# [CV] criterion=entropy, max_depth=5, max_features=auto, n_estimators=200
# [CV]  criterion=entropy, max_depth=5, max_features=auto, n_estimators=200, score=0.873, total=   3.3s
# [CV] criterion=entropy, max_depth=5, max_features=auto, n_estimators=200
# [CV]  criterion=entropy, max_depth=5, max_features=auto, n_estimators=200, score=0.867, total=   3.7s
# [CV] criterion=entropy, max_depth=5, max_features=auto, n_estimators=500
# [CV]  criterion=entropy, max_depth=5, max_features=auto, n_estimators=500, score=0.881, total=   6.9s
# [CV] criterion=entropy, max_depth=5, max_features=auto, n_estimators=500
# [CV]  criterion=entropy, max_depth=5, max_features=auto, n_estimators=500, score=0.867, total=   6.7s
# [CV] criterion=entropy, max_depth=5, max_features=auto, n_estimators=500
# [CV]  criterion=entropy, max_depth=5, max_features=auto, n_estimators=500, score=0.875, total=   7.3s
# [CV] criterion=entropy, max_depth=5, max_features=auto, n_estimators=500
# [CV]  criterion=entropy, max_depth=5, max_features=auto, n_estimators=500, score=0.865, total=   6.1s
# [CV] criterion=entropy, max_depth=5, max_features=auto, n_estimators=500
# [CV]  criterion=entropy, max_depth=5, max_features=auto, n_estimators=500, score=0.863, total=   6.7s
# [CV] criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=200
# [CV]  criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=200, score=0.878, total=   2.6s
# [CV] criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=200
# [CV]  criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=200, score=0.867, total=   2.5s
# [CV] criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=200
# [CV]  criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=200, score=0.871, total=   2.6s
# [CV] criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=200
# [CV]  criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=200, score=0.873, total=   2.6s
# [CV] criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=200
# [CV]  criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=200, score=0.867, total=   2.9s
# [CV] criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=500
# [CV]  criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=500, score=0.881, total=   7.0s
# [CV] criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=500
# [CV]  criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=500, score=0.867, total=   6.4s
# [CV] criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=500
# [CV]  criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=500, score=0.875, total=   6.2s
# [CV] criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=500
# [CV]  criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=500, score=0.865, total=   6.6s
# [CV] criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=500
# [CV]  criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=500, score=0.863, total=   6.6s
# [CV] criterion=entropy, max_depth=5, max_features=log2, n_estimators=200
# [CV]  criterion=entropy, max_depth=5, max_features=log2, n_estimators=200, score=0.874, total=   2.2s
# [CV] criterion=entropy, max_depth=5, max_features=log2, n_estimators=200
# [CV]  criterion=entropy, max_depth=5, max_features=log2, n_estimators=200, score=0.862, total=   2.2s
# [CV] criterion=entropy, max_depth=5, max_features=log2, n_estimators=200
# [CV]  criterion=entropy, max_depth=5, max_features=log2, n_estimators=200, score=0.871, total=   2.2s
# [CV] criterion=entropy, max_depth=5, max_features=log2, n_estimators=200
# [CV]  criterion=entropy, max_depth=5, max_features=log2, n_estimators=200, score=0.861, total=   2.2s
# [CV] criterion=entropy, max_depth=5, max_features=log2, n_estimators=200
# [CV]  criterion=entropy, max_depth=5, max_features=log2, n_estimators=200, score=0.856, total=   2.7s
# [CV] criterion=entropy, max_depth=5, max_features=log2, n_estimators=500
# [CV]  criterion=entropy, max_depth=5, max_features=log2, n_estimators=500, score=0.873, total=   6.8s
# [CV] criterion=entropy, max_depth=5, max_features=log2, n_estimators=500
# [CV]  criterion=entropy, max_depth=5, max_features=log2, n_estimators=500, score=0.863, total=   6.0s
# [CV] criterion=entropy, max_depth=5, max_features=log2, n_estimators=500
# [CV]  criterion=entropy, max_depth=5, max_features=log2, n_estimators=500, score=0.870, total=   6.9s
# [CV] criterion=entropy, max_depth=5, max_features=log2, n_estimators=500
# [CV]  criterion=entropy, max_depth=5, max_features=log2, n_estimators=500, score=0.861, total=   6.5s
# [CV] criterion=entropy, max_depth=5, max_features=log2, n_estimators=500
# [CV]  criterion=entropy, max_depth=5, max_features=log2, n_estimators=500, score=0.856, total=   5.5s
# [CV] criterion=entropy, max_depth=8, max_features=auto, n_estimators=200
# [CV]  criterion=entropy, max_depth=8, max_features=auto, n_estimators=200, score=0.902, total=   3.5s
# [CV] criterion=entropy, max_depth=8, max_features=auto, n_estimators=200
# [CV]  criterion=entropy, max_depth=8, max_features=auto, n_estimators=200, score=0.879, total=   3.7s
# [CV] criterion=entropy, max_depth=8, max_features=auto, n_estimators=200
# [CV]  criterion=entropy, max_depth=8, max_features=auto, n_estimators=200, score=0.890, total=   3.4s
# [CV] criterion=entropy, max_depth=8, max_features=auto, n_estimators=200
# [CV]  criterion=entropy, max_depth=8, max_features=auto, n_estimators=200, score=0.888, total=   3.8s
# [CV] criterion=entropy, max_depth=8, max_features=auto, n_estimators=200
# [CV]  criterion=entropy, max_depth=8, max_features=auto, n_estimators=200, score=0.875, total=   3.5s
# [CV] criterion=entropy, max_depth=8, max_features=auto, n_estimators=500
# [CV]  criterion=entropy, max_depth=8, max_features=auto, n_estimators=500, score=0.901, total=   8.4s
# [CV] criterion=entropy, max_depth=8, max_features=auto, n_estimators=500
# [CV]  criterion=entropy, max_depth=8, max_features=auto, n_estimators=500, score=0.878, total=   8.9s
# [CV] criterion=entropy, max_depth=8, max_features=auto, n_estimators=500
# [CV]  criterion=entropy, max_depth=8, max_features=auto, n_estimators=500, score=0.889, total=   8.3s
# [CV] criterion=entropy, max_depth=8, max_features=auto, n_estimators=500
# [CV]  criterion=entropy, max_depth=8, max_features=auto, n_estimators=500, score=0.890, total=   8.8s
# [CV] criterion=entropy, max_depth=8, max_features=auto, n_estimators=500
# [CV]  criterion=entropy, max_depth=8, max_features=auto, n_estimators=500, score=0.875, total=  10.8s
# [CV] criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=200
# [CV]  criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=200, score=0.902, total=   3.7s
# [CV] criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=200
# [CV]  criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=200, score=0.879, total=   3.5s
# [CV] criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=200
# [CV]  criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=200, score=0.890, total=   3.5s
# [CV] criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=200
# [CV]  criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=200, score=0.888, total=   3.8s
# [CV] criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=200
# [CV]  criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=200, score=0.875, total=   3.5s
# [CV] criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=500
# [CV]  criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=500, score=0.901, total=   9.4s
# [CV] criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=500
# [CV]  criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=500, score=0.878, total=   9.6s
# [CV] criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=500
# [CV]  criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=500, score=0.889, total=   8.5s
# [CV] criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=500
# [CV]  criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=500, score=0.890, total=   8.7s
# [CV] criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=500
# [CV]  criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=500, score=0.875, total=   8.8s
# [CV] criterion=entropy, max_depth=8, max_features=log2, n_estimators=200
# [CV]  criterion=entropy, max_depth=8, max_features=log2, n_estimators=200, score=0.895, total=   3.0s
# [CV] criterion=entropy, max_depth=8, max_features=log2, n_estimators=200
# [CV]  criterion=entropy, max_depth=8, max_features=log2, n_estimators=200, score=0.882, total=   3.2s
# [CV] criterion=entropy, max_depth=8, max_features=log2, n_estimators=200
# [CV]  criterion=entropy, max_depth=8, max_features=log2, n_estimators=200, score=0.892, total=   3.0s
# [CV] criterion=entropy, max_depth=8, max_features=log2, n_estimators=200
# [CV]  criterion=entropy, max_depth=8, max_features=log2, n_estimators=200, score=0.887, total=   3.0s
# [CV] criterion=entropy, max_depth=8, max_features=log2, n_estimators=200
# [CV]  criterion=entropy, max_depth=8, max_features=log2, n_estimators=200, score=0.868, total=   3.0s
# [CV] criterion=entropy, max_depth=8, max_features=log2, n_estimators=500
# [CV]  criterion=entropy, max_depth=8, max_features=log2, n_estimators=500, score=0.895, total=   7.5s
# [CV] criterion=entropy, max_depth=8, max_features=log2, n_estimators=500
# [CV]  criterion=entropy, max_depth=8, max_features=log2, n_estimators=500, score=0.883, total=   7.7s
# [CV] criterion=entropy, max_depth=8, max_features=log2, n_estimators=500
# [CV]  criterion=entropy, max_depth=8, max_features=log2, n_estimators=500, score=0.888, total=   8.0s
# [CV] criterion=entropy, max_depth=8, max_features=log2, n_estimators=500
# [CV]  criterion=entropy, max_depth=8, max_features=log2, n_estimators=500, score=0.886, total=   8.2s
# [CV] criterion=entropy, max_depth=8, max_features=log2, n_estimators=500
# [CV]  criterion=entropy, max_depth=8, max_features=log2, n_estimators=500, score=0.870, total=   8.2s
# [CV] criterion=entropy, max_depth=10, max_features=auto, n_estimators=200
# [CV]  criterion=entropy, max_depth=10, max_features=auto, n_estimators=200, score=0.902, total=   4.2s
# [CV] criterion=entropy, max_depth=10, max_features=auto, n_estimators=200
# [CV]  criterion=entropy, max_depth=10, max_features=auto, n_estimators=200, score=0.888, total=   4.7s
# [CV] criterion=entropy, max_depth=10, max_features=auto, n_estimators=200
# [CV]  criterion=entropy, max_depth=10, max_features=auto, n_estimators=200, score=0.898, total=   4.6s
# [CV] criterion=entropy, max_depth=10, max_features=auto, n_estimators=200
# [CV]  criterion=entropy, max_depth=10, max_features=auto, n_estimators=200, score=0.896, total=   4.5s
# [CV] criterion=entropy, max_depth=10, max_features=auto, n_estimators=200
# [CV]  criterion=entropy, max_depth=10, max_features=auto, n_estimators=200, score=0.878, total=   4.5s
# [CV] criterion=entropy, max_depth=10, max_features=auto, n_estimators=500
# [CV]  criterion=entropy, max_depth=10, max_features=auto, n_estimators=500, score=0.902, total=  11.1s
# [CV] criterion=entropy, max_depth=10, max_features=auto, n_estimators=500
# [CV]  criterion=entropy, max_depth=10, max_features=auto, n_estimators=500, score=0.887, total=  10.1s
# [CV] criterion=entropy, max_depth=10, max_features=auto, n_estimators=500
# [CV]  criterion=entropy, max_depth=10, max_features=auto, n_estimators=500, score=0.895, total=  10.1s
# [CV] criterion=entropy, max_depth=10, max_features=auto, n_estimators=500
# [CV]  criterion=entropy, max_depth=10, max_features=auto, n_estimators=500, score=0.897, total=   9.8s
# [CV] criterion=entropy, max_depth=10, max_features=auto, n_estimators=500
# [CV]  criterion=entropy, max_depth=10, max_features=auto, n_estimators=500, score=0.881, total=  11.3s
# [CV] criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV]  criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200, score=0.902, total=   4.2s
# [CV] criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV]  criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200, score=0.888, total=   4.5s
# [CV] criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV]  criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200, score=0.898, total=   3.9s
# [CV] criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV]  criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200, score=0.896, total=   4.7s
# [CV] criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV]  criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200, score=0.878, total=   4.3s
# [CV] criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=500
# [CV]  criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=500, score=0.902, total=  11.3s
# [CV] criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=500
# [CV]  criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=500, score=0.887, total=  11.8s
# [CV] criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=500
# [CV]  criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=500, score=0.895, total=  10.2s
# [CV] criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=500
# [CV]  criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=500, score=0.897, total=  10.0s
# [CV] criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=500
# [CV]  criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=500, score=0.881, total=   9.9s
# [CV] criterion=entropy, max_depth=10, max_features=log2, n_estimators=200
# [CV]  criterion=entropy, max_depth=10, max_features=log2, n_estimators=200, score=0.896, total=   3.4s
# [CV] criterion=entropy, max_depth=10, max_features=log2, n_estimators=200
# [CV]  criterion=entropy, max_depth=10, max_features=log2, n_estimators=200, score=0.883, total=   3.5s
# [CV] criterion=entropy, max_depth=10, max_features=log2, n_estimators=200
# [CV]  criterion=entropy, max_depth=10, max_features=log2, n_estimators=200, score=0.893, total=   3.3s
# [CV] criterion=entropy, max_depth=10, max_features=log2, n_estimators=200
# [CV]  criterion=entropy, max_depth=10, max_features=log2, n_estimators=200, score=0.893, total=   3.4s
# [CV] criterion=entropy, max_depth=10, max_features=log2, n_estimators=200
# [CV]  criterion=entropy, max_depth=10, max_features=log2, n_estimators=200, score=0.878, total=   3.4s
# [CV] criterion=entropy, max_depth=10, max_features=log2, n_estimators=500
# [CV]  criterion=entropy, max_depth=10, max_features=log2, n_estimators=500, score=0.898, total=   8.6s
# [CV] criterion=entropy, max_depth=10, max_features=log2, n_estimators=500
# [CV]  criterion=entropy, max_depth=10, max_features=log2, n_estimators=500, score=0.882, total=   8.7s
# [CV] criterion=entropy, max_depth=10, max_features=log2, n_estimators=500
# [CV]  criterion=entropy, max_depth=10, max_features=log2, n_estimators=500, score=0.896, total=   8.6s
# [CV] criterion=entropy, max_depth=10, max_features=log2, n_estimators=500
# [CV]  criterion=entropy, max_depth=10, max_features=log2, n_estimators=500, score=0.893, total=   8.6s
# [CV] criterion=entropy, max_depth=10, max_features=log2, n_estimators=500
# [CV]  criterion=entropy, max_depth=10, max_features=log2, n_estimators=500, score=0.877, total=   9.2s
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed: 16.3min finished
# GridSearchCV(estimator=RandomForestClassifier(random_state=1),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [5, 8, 10],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [200, 500]},
#              verbose=3)

# %%
print(grid_rf.best_params_)
print(grid_rf.best_score_)
# Out:
# {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 500}
# 0.8922359717360774

# %%
predictions = grid_rf.predict(X_test)

# %%
# Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions,
                           target_names =["CONFIRMED", "FALSE POSITIVE", "CANDIDATE"]))
# Out:
#                 precision    recall  f1-score   support
#
#      CONFIRMED       0.84      0.69      0.76       427
# FALSE POSITIVE       0.76      0.84      0.80       451
#      CANDIDATE       0.97      1.00      0.98       870
#
#       accuracy                           0.88      1748
#      macro avg       0.86      0.84      0.85      1748
#   weighted avg       0.88      0.88      0.88      1748

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'best_models/randomForestClassifier.sav'
joblib.dump(grid_rf, filename)
# Out:
# ['best_models/randomForestClassifier.sav']
